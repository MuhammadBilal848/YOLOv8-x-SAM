# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadBilal848/YOLOv8-x-SAM/blob/main/Yolov8_x_Sam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/Colab Notebooks/Folio3
# Out:
# /content/drive/MyDrive/Colab Notebooks/Folio3

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Folio3'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.0/608.0 kB 7.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2 as cv
import numpy as np
import pickle
import matplotlib.pyplot as plt
import math

# %%
model = YOLO('/content/drive/MyDrive/Colab Notebooks/Folio3/yolo_weights/yolov8n.pt')

# %%
import cv2 as cv
import math

# OpenCV VideoCapture
capture = cv.VideoCapture('/content/drive/MyDrive/Colab Notebooks/Folio3/video/fruitsnveggies.mp4')
output_path = '/content/drive/MyDrive/Colab Notebooks/Folio3/runs/detect/output_video.avi'

# Define the codec and create VideoWriter object
frame_width = int(capture.get(3))
frame_height = int(capture.get(4))

size = (frame_width, frame_height)
out = cv.VideoWriter(output_path, cv.VideoWriter_fourcc(*'MJPG'),10, size)
while True:
    ret, frame = capture.read()
    result = model(frame, stream=True)

    if not ret:
        # Break the loop if there are no more frames to read
        break

    for r in result:
        boxes = r.boxes
        for coord in boxes:
            xmin, ymin, xmax, ymax = coord.xyxy[0]
            xmin, ymin, xmax, ymax = int(xmin), int(ymin), int(xmax), int(ymax)
            bbox = xmin, ymin, xmax - xmin, ymax - ymin

            confidence = (math.ceil(coord.conf[0] * 100)) / 100
            clsname = int(coord.cls[0])

            # Draw bounding box and class name on the frame
            cv.rectangle(frame, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
            cv.putText(frame, f'Class: {clsname} - Confidence: {confidence}', (xmin, ymin - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Write the modified frame to the output video
    # output_video.write(frame)
    out.write(frame)


# Release VideoCapture and VideoWriter
capture.release()
output_video.release()

print('ENDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD!!!!')
# Out:
# 0: 384x640 (no detections), 169.3ms
# Speed: 3.2ms preprocess, 169.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.6ms
# Speed: 3.1ms preprocess, 98.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.6ms
# Speed: 3.0ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.9ms
# Speed: 3.2ms preprocess, 102.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.1ms
# Speed: 1.9ms preprocess, 99.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 4.4ms preprocess, 95.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# %cd {HOME}

import sys
# !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-z1d126bs
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-z1d126bs
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36589 sha256=46c3db91132ddfb38ea163aef02844257c933f0056ec5662429eb30767461e78
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0b85li0u/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# ...

# %%
# !pip install -q jupyter_bbox_widget roboflow dataclasses-json supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.3 MB/s eta 0:00:00
# ...

# %%
import os
CHECKPOINT_PATH = '/content/drive/MyDrive/Colab Notebooks/Folio3/sam_weights/sam_vit_h_4b8939.pth'
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/drive/MyDrive/Colab Notebooks/Folio3/sam_weights/sam_vit_h_4b8939.pth ; exist: True

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %%
IMAGE_PATH = "/content/drive/MyDrive/Colab Notebooks/Folio3/Red chilli.png"
# IMAGE_PATH = os.path.join(HOME, "data", IMAGE_NAME)

# %%
import cv2
import supervision as sv

image_bgr = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

sam_result = mask_generator.generate(image_rgb)

# %%
mask_annotator = sv.MaskAnnotator()

detections = sv.Detections.from_sam(sam_result=sam_result)

annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[image_bgr, annotated_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %%
masks = [
    mask['segmentation']
    for mask
    in sorted(sam_result, key=lambda x: x['area'], reverse=True)
]

sv.plot_images_grid(
    images=masks,
    grid_size=(15, int(len(masks) / 8)),
    size=(16, 16)
)
